# %%
import gym

# Open AI Gymに登録されている環境（ゲーム）を列挙
envids = [spec.id for spec in gym.envs.registry.all()]
envids
# Out:
# ['Enduro-ramNoFrameskip-v0',
#  'ChopperCommand-ramNoFrameskip-v0',
#  'KangarooNoFrameskip-v0',
#  'Boxing-v4',
#  'BeamRider-v0',
#  'Pooyan-ramDeterministic-v4',
#  'Phoenix-ramNoFrameskip-v4',
#  'BankHeist-v4',
#  'Kangaroo-ramDeterministic-v4',
#  'DoubleDunk-ramDeterministic-v0',
#  'PrivateEye-ram-v4',
#  'CrazyClimber-ramNoFrameskip-v4',
#  'Riverraid-v4',
#  'HeroDeterministic-v0',
#  'CrazyClimber-ram-v4',
#  'UpNDown-ramDeterministic-v0',
#  'Venture-ram-v0',
#  'Qbert-v0',
#  'MsPacmanNoFrameskip-v0',
#  'Asteroids-ramNoFrameskip-v0',
#  'CrazyClimber-ramDeterministic-v4',
#  'Riverraid-ramDeterministic-v4',
#  'DemonAttackDeterministic-v4',
#  'Alien-ram-v4',
#  'MsPacman-ramNoFrameskip-v4',
#  'DuplicatedInput-v0',
#  'Amidar-ramDeterministic-v0',
#  'KangarooDeterministic-v4',
#  'Tutankham-ramNoFrameskip-v4',
#  'DoubleDunk-v0',
#  'MontezumaRevenge-ramDeterministic-v0',
#  'Carnival-v4',
#  'Seaquest-ram-v4',
#  'Frostbite-ram-v0',
#  'KungFuMasterNoFrameskip-v0',
# ...

# %%
# MountainCar: 車で山登りするゲーム をロード
env = gym.make('MountainCar-v0')

# 環境を初期化
observation = env.reset() # observationに初期状態格納
observation
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# array([-0.59871327,  0.        ])

# %%
# MountainCarの観測データを取得
print(env.observation_space)

# 観測データの最大値
print(env.observation_space.high)

# 観測データの最小値
print(env.observation_space.low)
# Out:
# Box(2,)
# [0.6  0.07]
# [-1.2  -0.07]

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
 
    def animate(i):
        patch.set_data(frames[i])
 
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)
 
    #anim.save('movie_cartpole.mp4')  # 追記：動画の保存です
    display(display_animation(anim, default_mode='loop'))

# %%
plt.imshow(env.render(mode='rgb_array'))
env.close()

# %%
observation = env.reset() # observationに初期状態格納
observation
# Out:
# array([-0.56199133,  0.        ])

# %%
display_frames_as_gif([env.render(mode='rgb_array')])
env.close()
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
# エージェントを動かす
'''
MountainCar-v0（山登り）の場合、アクションの値はそれぞれ以下の通り。
0: 左へ押す
1: 何もしない
2: 右へ押す
'''

print(env.action_space) # 取れる行動空間
action = 0 # 左
observation, reward, done, info = env.step(action)
observation, reward, done, info
# Out:
# Discrete(3)
# (array([-0.56270402, -0.00071269]), -1.0, False, {})
